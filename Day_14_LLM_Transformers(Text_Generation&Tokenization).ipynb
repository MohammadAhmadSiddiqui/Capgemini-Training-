# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadAhmadSiddiqui/Capgemini-Training-/blob/main/Day_14_LLM_Transformers(Text_Generation%26Tokenization).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Generation
#
#  Scenario: AI‑Powered Email Assistant
#
# You’re building an email drafting assistant for a corporate team.
#  - When a user starts typing:
#  “Artificial Intelligence will…”
#  - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
#  - Example output:
#  “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')
print(generator("Artificial Intelligence will",max_length=30))
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Artificial Intelligence will be used to solve problems like disease and crime.\n\nThe most important thing we do with AI is to understand how to do things with human brains. People are going to tell you that we can do a lot of things with our brains, but we have no idea how to do it with robots.\n\nWe don't have any idea what we're doing with our brains. There are many, many things that we don't understand about AI. A lot of people think of the whole human brain as a computer. But that is not the case. People are just trying to understand how our brains work, and they're not understanding their brains.\n\nSome of my colleagues have suggested that the human brain is not the only thing that we have to learn from our brains. In fact, the whole human brain is almost entirely in sync with our brain. People are already working with our brains on a number of areas that we need to learn, and because we have a lot of brain, they're working on a few areas all over the brain.\n\nThe most interesting thing with the human brain is that it's very flexible. It's very flexible in a way that we haven't been able to adapt to before. It's very resilient. If we are allowed"}]

# %% [markdown]
#   Scenario: Game Storyline Generator
#  You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
#  - The developer types a prompt:
#  “The hero enters the ancient forest and discovers…”
#  - The GPT‑2 pipeline continues the story:
#  “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#   a cursed artifact buried beneath the old ruins.”

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')
print(generator("The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins",max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins.\n\nThe battle is fierce, with the hero and his companions in the darkness. It is the story of the heroes of the ancient world, facing an ancient threat. The heroes fight to save their lives and those of the people of the world.\n\nThe heroes are united and are united in their quest for justice and justice for all. The heroes take the ancient village beneath the ruins, and fight to save its people.\n\nThe hero finds the ruins, and finds a mysterious weapon hidden in the ruins. The hero uses the weapon to destroy the artifact, and the villagers fight to save the artifact.\n\nThe hero discovers that the artifact has been destroyed, but he does not know why. The hero confronts the evil man. The hero is confronted by the evil, and the evil takes him to the mysterious weapon. The heroes fight to save their lives, and the evil takes them to the mysterious weapon.\n\nThe hero finds the artifact and finds it, and finds the man in the artifact, and the man in the artifact. The hero realizes that he has lost, and that the artifact is his.\n\nThe hero uses the weapon to destroy the artifact, and the villagers fight to save the artifact. The hero finds the artifact, and discovers'}]

# %% [markdown]
# # Tokenization

# %% [markdown]
# Scenario: Research Assistant for Academic Papers
#
#  Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
#  - A researcher uploads a sentence:
#  “Deep learning models are powerful”
#  - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained('bert-base-cased')

text="Deep learning models are powerful"
tokens=tokenizer.tokenize(text)
print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['Deep', 'learning', 'models', 'are', 'powerful']

# %% [markdown]
#  🏥 Scenario: Healthcare Chatbot for Patient Queries
#
#  A hospital is developing a chatbot to help patients ask questions about their health.
#  - A patient types:
#  “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
#  - The chatbot uses the BERT tokenizer to break the sentence into tokens:

# %%
from transformers import AutoTokenizer
tokenizer=AutoTokenizer.from_pretrained('bert-base-cased')

text="I have chest pain and shortness of breath"
tokens=tokenizer.tokenize(text)
print(tokens)
# Out:
# ['I', 'have', 'chest', 'pain', 'and', 'short', '##ness', 'of', 'breath']

# %% [markdown]
# # Text Generation with Randomness(Temprature)

# %% [markdown]
#  Scenario: Exploring Creativity in AI Writing
#
#  A university professor is running a workshop on creative writing with AI.
#  - The professor gives students the prompt:
#  “The future of Artificial Intelligence”
#  - The system uses GPT‑2 to generate continuations of the sentence.
#  To demonstrate how temperature affects creativity:
#  - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
#  “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')

prompt="The future of Artificial Intelligence"
print(generator(prompt,max_length=30,temperature=0.2))
print(generator(prompt,max_length=30,temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Passing `generation_config` together with generation-related arguments=({'temperature', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is now in question.\n\nThe question is, how will we get there?\n\nThe answer is that we will need to start thinking about the future.\n\nThe future is not a single, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular, singular,'}]
# [{'generated_text': 'The future of Artificial Intelligence in the 21st century," said Professor Eric K. Brown, the author of Artificial Intelligence: The Rise and Fall of Our World. "If we can harness this power, we can harness all kinds of technologies in the future to create a world that has a higher level of freedom than we do today.\n\n"What will we learn about the future of AI? What will we learn about the future of human civilization? And what will we learn about the future of science?"\n\nThe findings are published in a report from the American Association of University Women. "We are a part of a broader group of women who live a lives full of hope, hopelessness and hopelessness," said Lillian Miller, President of Artificial Intelligence Research Lab at the University of California, San Francisco. "We are the first to consider the future of AI beyond the human race as a possible outcome of our human-driven technological transformation, and we believe that this future is the only that we can make. We\'re very excited about this and hope that we can inspire women, as well as men of all races, to take to the streets in protest against the current status quo for women in the tech world."'}]

# %% [markdown]
#   Scenario: Scriptwriting Assistant for Film Production
#
#  A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
#  - The writer provides the prompt:
#  “The future of Artificial Intelligence”
#  - The system generates two versions of the continuation:
#  - Temperature = 0.2 (low randomness)
#  Output is more predictable and formal, e.g.:
#  “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
#  → This is useful for serious, factual narration in a documentary script.
#  - Temperature = 0.8 (higher randomness)
#  Output is more imaginative and varied, e.g.:
#  “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
#  → This is perfect for creative dialogue or speculative sci‑fi storytelling

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')

prompt="The future of Aritifical Intelligence in movie production"
print()
print("Temperature=0.2")
print(generator(prompt,max_length=30,temperature=0.2))
print("Temperature=0.8")
print(generator(prompt,max_length=30,temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Temperature=0.2
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Aritifical Intelligence in movie production is uncertain.\n\n"We\'re not sure what the future holds for Aritifical Intelligence," said David L. Burt, a professor of history at the University of California, Berkeley. "We\'re not sure what the future holds for Aritifical Intelligence. We\'re not sure what the future holds for Aritifical Intelligence. We\'re not sure what the future holds for Aritifical Intelligence."\n\nThe movie, which is based on the book by the same name, is set in the same year as the first Aritifical Intelligence film, "The Big Lebowski."\n\nThe film is based on the book by the same name, which is based on the book by the same name.\n\nThe film is based on the book by the same name, which is based on the book by the same name.\n\nThe film is based on the book by the same name, which is based on the book by the same name.\n\nThe film is based on the book by the same name, which is based on the book by the same name.\n\nThe film is based on the book by the same name, which is based on the book by the same name.\n\nThe film is based'}]
# Temperature=0.8
# [{'generated_text': 'The future of Aritifical Intelligence in movie production will be defined by the emergence of a new intelligence agency.\n\n"I am an expert in the field of Aritifical Intelligence," says H.J. DeMille, director of the Department of Foreign Affairs at Georgetown University\'s School of Advanced International Studies. "Aritifical intelligence is a new type of intelligence that is more and more relevant to the way we understand what we see in the world, how we think and we think about the world. And it\'s not just that we don\'t know what we see, but it\'s that we don\'t have sufficient time to do a good job. It is the ability to gather so much information with so little time that makes it worth every second of each second. It is a new intelligence technique."\n\nThe new intelligence agency is a combination of two intelligence products: the Aritifical Intelligence Unit (AIPU), which would be responsible for coordinating and coordinating all intelligence tasks and the Aritifical Intelligence Security Unit (AISU), which would provide management and technical advice to the security services.\n\n"For Aritifical Intelligence, the Aritifical Intelligence Unit is a new intelligence tool for the security service," says DeMille. "The AIFU is'}]

# %% [markdown]
# # Scenario: AI‑Powered News Headline Generator
#  A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
#  - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
#  - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
#  - Example output:
#  “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')
prompt=input("Enter a prompt:")
output=generator(prompt,max_length=50)
print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt:Tell me about some Current affairs happening on earth
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Tell me about some Current affairs happening on earth today. I have no idea how to describe it.
#
# I have no idea how to say "yes" to what I hear.
#
# I have no idea how to say "no" to a person who is not a Christian.
#
# I have no idea how to say "no" to people who are not Christian.
#
# I have no idea how to say "no" to people who are not a Muslim.
#
# I have no idea how to say "no" to my friends.
#
# I have no idea how to say "no" to my children.
#
# I have no idea how to say "no" to my grandchildren.
#
# I have no idea how to say "no" to anyone.
#
# I have no idea how to say "no" to anyone who is not a Muslim.
#
# I have no idea how to say "no" to people who are not a Christian.
#
# I have no idea how to say "no" to anyone who is not a Muslim.
#
# I have no idea how to say "no" to anyone who is not a Muslim.
#
# I have no idea how to say "no" to anyone who is not a Christian.
#
# I have no

# %% [markdown]
# # 🎓 Scenario: Student Brainstorming Tool for Essay Writing
#
#  A college student is struggling to start their essay.
#  - The system prompts them:
#  “Enter a prompt:”
#  - The student types:
#  “The impact of technology on education”
#  - The GPT‑2 model generates a continuation up to 50 tokens, for example:
#  “The impact of technology on education has transformed classrooms, enabling online learning,
#  personalized study plans, and global collaboration among students.”

# %%
from transformers import pipeline

generator=pipeline('text-generation',model='gpt2')
prompt=input("Enter a prompt:")
output=generator(prompt,max_length=50)
print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt:The impact of technology on education
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The impact of technology on education is profound, and when it does, we have to be very careful about how we teach it," said David Daley, the head of the School of Public Health at the University of New South Wales.
#
# "This is the first time in the country that we've had a major national data breach of a school, or of a major public health system, which has been linked to a breach of data."
#
# "It's very concerning. We know that there are some students in Australia whose data is very valuable, and it's not easy to get around it, and we have to be very careful about what we teach about that."
#
# Daley said there were some lessons to be learned from this incident.
#
# "There are certain things that are important to know about your local school system, but they need to be taken into account when you are educating students," he said.
#
# Mr Daley said the NSW Government should take measures to ensure students are receiving the best education in the country.
#
# "We need to have a national data breach alert system, with the best possible response system, and that's what we're doing," he said.
#
# "We need to know what we're doing about it and what's happening in some

# %% [markdown]
# GPT-2 vs DistilGPT‑2

# %% [markdown]
# # Scenario: AI Model Evaluation in a Startup
#
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
#  - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
#  - They use the same prompt:
#  “Artificial Intelligence will transform”
#  - The system generates two outputs:
#  - GPT‑2 Output
#  Longer, more detailed continuation, e.g.:
#  “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
#  reshaping how humans interact with technology.”
#  → Richer but slower to run.
#  - DistilGPT‑2 Output

# %%
from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"
print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform industries, from agriculture to defense, to medicine, to public health, to finance, to law and order, to agriculture. It will create new jobs, new opportunities, new opportunities for people. If humanity continues to do that, it will not only be at a disadvantage, it will be a disadvantage for the planet. It will be a disadvantage for humankind by its own actions.\n\nIf we continue to ignore the facts, we will have a very different future. We will be replaced by a country in which we will have to live in the shadows and be governed by the people. We will have to live in the shadows in order to protect and protect our people. We will have to live in the shadows in order to protect our country.\n\nWe will have to live in the shadows in order to defend our people. We will have to live in the shadows in order to protect our country.\n\nWe will have to live in the shadows in order to protect our country, and we will have to live in the shadows in order to protect our country.\n\nAs the United Nations continues to set up offices in every part of the world to coordinate the development of world peace and security, and to support the international community, we will have to be able to'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will transform the way we think about science and society. It will change the way we think'}]

# %% [markdown]
# # Scenario: Educational Tool for Classroom Learning
#
# A high school teacher is introducing students to AI‑powered writing assistants.
#  - The teacher wants to show how different models produce different styles of text.
#  - They use the same prompt:
#  “Artificial Intelligence will transform the society”
#  - The system generates two outputs:
#  - GPT‑2 Output
#  More elaborate continuation, e.g.:
#  “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
#  → Great for showing students how AI can generate rich, detailed ideas.
#  - DistilGPT‑2 Output
#  Shorter, faster continuation, e.g.:
#  “Artificial Intelligence will transform our daily lives.”
#  → Useful for demonstrating concise summaries.

# %%
from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform the society"
print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the society into a digital war zone.\n\nThe rise of artificial intelligence is already causing some major problems for the political system in the EU. The rise of artificial intelligence is already causing some major problems for the political system in the EU.\n\nA new report from the European Commission on Thursday warns that the EU is facing a national crisis.\n\nIt says that the European Commission has been working hard to protect the integrity of the Schengen zone, which is the first step towards a "comprehensive" EU data protection agreement.\n\nThe report is the latest in a series by the commission\'s European Policy Centre which has been focused on the issue of data protection for the EU for more than a decade.\n\nThe commission\'s report, entitled "Unitary and integrated data protection in the 21st century: an innovative strategy for better cooperation" was published in August 2014.\n\nIt argues that the EU must ensure that data sharing is as seamless as possible between citizens and providers of services.\n\n"The EU must ensure that the European Union\'s common data protection rules are in place to ensure that the rules for online services are as harmonious as possible", the commission says in its report.\n\n"In particular, the EU must ensure that the European'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform the society in which we live. It will lead to a change of the way we live, and to change the way we live. But it will not change the way we live.\n\n\n\n\nThe idea of artificial intelligence is a cornerstone of human society. The idea is that we have to create new kinds of intelligence. We have to create new kinds of intelligence that can be used to make people happier, and to allow them to grow for themselves.\nBut we cannot create new kinds of intelligence that can be used to cause people to feel less satisfied. We have to create new kinds of intelligence that can be used to make people happier.\nThe idea of artificial intelligence is a cornerstone of human society. The idea is that we have to create new kinds of intelligence that can be used to make people happier.\nWhat is artificial intelligence?\nThe idea of artificial intelligence is a cornerstone of human society. The idea is that we have to create new kinds of intelligence that can be used to make people happier.\nThis idea is based on the idea of artificial intelligence. It is based on the idea of artificial intelligence. It is based on the idea of artificial intelligence. It is based on the idea of artificial intelligence. It is based on the idea of artificial intelligence. It'}]
