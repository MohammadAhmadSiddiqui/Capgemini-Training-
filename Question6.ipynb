# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammadAhmadSiddiqui/Capgemini-Training-/blob/main/Question6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fca25b0d-5777-47f3-be80-280238646f05" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fca25b0d-5777-47f3-be80-280238646f05">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("Dataset  - Sheet1.csv")

df.head()
# Out:
#   Employee Department Quarter  Score
# 0     Amit      Sales      Q1     78
# 1    Priya         HR      Q1     85
# 2     John         IT      Q1     92
# 3     Sara    Finance      Q1     88
# 4    David      Sales      Q2     95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Employee    10 non-null     object
#  1   Department  10 non-null     object
#  2   Quarter     10 non-null     object
#  3   Score       10 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 452.0+ bytes

# %%
df.describe()
# Out:
#            Score
# count  10.000000
# mean   85.300000
# std     9.177872
# min    70.000000
# 25%    78.500000
# 50%    86.500000
# 75%    91.500000
# max    99.000000

# %%
top_performers = df[df["Score"] > 90]
print(top_performers)
sales_data = df[df["Department"] == "Sales"]
print(sales_data)
df_sorted = df.sort_values(by="Score", ascending=False)
print(df_sorted)
df_dept_sorted = df.sort_values(by=["Department", "Score"], ascending=[True, False])
print(df_dept_sorted)
avg_dept_score = df.groupby("Department")["Score"].mean()
print(avg_dept_score)
max_quarter_score = df.groupby("Quarter")["Score"].max()
print(max_quarter_score)
avg_dept_score.plot(kind="bar", title="Average Score per Department")
# Out:
#   Employee Department Quarter  Score
# 2     John         IT      Q1     92
# 4    David      Sales      Q2     95
# 8     Neha      Sales      Q3     99
#   Employee Department Quarter  Score
# 0     Amit      Sales      Q1     78
# 4    David      Sales      Q2     95
# 8     Neha      Sales      Q3     99
#   Employee Department Quarter  Score
# 8     Neha      Sales      Q3     99
# 4    David      Sales      Q2     95
# 2     John         IT      Q1     92
# 7     Ravi    Finance      Q2     90
# 3     Sara    Finance      Q1     88
# 1    Priya         HR      Q1     85
# 5    Meera         HR      Q2     80
# 0     Amit      Sales      Q1     78
# 9    Karan         IT      Q3     76
# 6     Alex         IT      Q2     70
#   Employee Department Quarter  Score
# 7     Ravi    Finance      Q2     90
# 3     Sara    Finance      Q1     88
# 1    Priya         HR      Q1     85
# 5    Meera         HR      Q2     80
# 2     John         IT      Q1     92
# ...
